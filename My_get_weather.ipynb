# %%
#province: Drenthe
#crop: maize(green)
#year: 2022-04-01 to 2022-11-21
#This notebook retrives meteological data from KNMI GRIB files, based on the coordinates of plots in Drenthe
# and save them as CSV files that can be used in WOFOST ensenmble simulation

# %% [markdown]
# #### Processing meteorological data

# %%
import warnings
warnings.filterwarnings("ignore", message="GRIB: .*", category=RuntimeWarning)
#ignore the warnings

# %%
import fpcup
fpcup.test()
# Out:
# Succesfully imported fpcup version 0.0.1 from C:\Users\Suliko\q34\25q3\thesis\fpcup_new\fpcup-main\fpcup\__init__.py.

# %%
# Setup
year = 2022
brp = fpcup.io.load_brp(year)
crop_species = "barley"
province = fpcup.geo.process_input_province("Drenthe")
brp_plots = fpcup.io.query_brp(brp, province=province, crop_species=crop_species)
brp_plots #brp plots in Drenthe. totally 5048 plots
# Out:
#                    crop  crop_code province       area crop_species  \
# 65      barley (spring)        236       DR   4.754415       barley
# 84      barley (spring)        236       DR  11.200659       barley
# 171     barley (spring)        236       DR   1.531765       barley
# 172     barley (spring)        236       DR   8.576494       barley
# 220     barley (spring)        236       DR   2.549430       barley
# ...                 ...        ...      ...        ...          ...
# 114164  barley (spring)        236       DR   2.004656       barley
# 114165  barley (spring)        236       DR   2.511491       barley
# 114295  barley (spring)        236       DR   1.027462       barley
# 114359  barley (spring)        236       DR   3.978249       barley
# 114461  barley (winter)        235       DR   4.948594       barley
#
#          latitude  longitude  \
# 65      52.796016   6.882431
# 84      52.838428   7.054879
# 171     52.904292   6.910060
# ...

# %%
brp_barley = brp_plots[brp_plots["crop"] == "barley (winter)"]

# %%
brp_barley
# Out:
#                    crop  crop_code province       area crop_species  \
# 268     barley (winter)        235       DR   2.377218       barley
# 269     barley (winter)        235       DR   1.871636       barley
# 270     barley (winter)        235       DR   1.006191       barley
# 415     barley (winter)        235       DR  20.157236       barley
# 482     barley (winter)        235       DR   1.389190       barley
# ...                 ...        ...      ...        ...          ...
# 105248  barley (winter)        235       DR   6.023288       barley
# 108603  barley (winter)        235       DR  31.670920       barley
# 110271  barley (winter)        235       DR   0.519363       barley
# 113503  barley (winter)        235       DR   7.016160       barley
# 114461  barley (winter)        235       DR   4.948594       barley
#
#          latitude  longitude  \
# 268     52.767790   6.725163
# 269     52.768060   6.723638
# 270     52.767717   6.726866
# ...

# %%
# brp_maize = brp_plots[brp_plots["crop"] == "maize (green)"]
# brp_maize
# Out:
#                  crop  crop_code province       area crop_species   latitude  \
# 49      maize (green)        259       DR   1.243862        maize  52.850283
# 115     maize (green)        259       DR   1.343735        maize  52.755400
# 167     maize (green)        259       DR   1.843291        maize  52.750754
# 244     maize (green)        259       DR   4.483355        maize  52.640474
# 267     maize (green)        259       DR   3.204383        maize  52.745783
# ...               ...        ...      ...        ...          ...        ...
# 114356  maize (green)        259       DR   1.821246        maize  53.015989
# 114387  maize (green)        259       DR   1.424741        maize  52.765242
# 114388  maize (green)        259       DR   3.032424        maize  52.737648
# 114403  maize (green)        259       DR   3.177108        maize  52.727277
# 114425  maize (green)        259       DR  10.120581        maize  52.890265
#
# ...

# %%
#too many points, take too much time to compute
#employe k-means to reduce the number of points

# %%
from sklearn.cluster import KMeans

X = brp_barley[["latitude", "longitude"]]
brp_barley["cluster"] = KMeans(n_clusters=50, random_state=42).fit_predict(X)

sampled = brp_barley.groupby("cluster").apply(lambda x: x.sample(1)).reset_index(drop=True)

# %%
sampled.to_csv("./sampled_points_barley_spring.csv", index=False)

# %%
brp_barley.to_csv("./barley_points.csv", index=False)

# %%
from osgeo import gdal
import numpy as np

# %%
#inspect the grib file
def inspect_rh_by_band(fpath, rh_band=27):
    ds = gdal.Open(fpath, gdal.GA_ReadOnly)
    if ds is None:
        raise FileNotFoundError(f"Cannot open: {fpath}")
    print("RasterCount:", ds.RasterCount)

    if rh_band > ds.RasterCount:
        raise IndexError(f"Band {rh_band} > RasterCount {ds.RasterCount}")

    b = ds.GetRasterBand(rh_band)
    md = b.GetMetadata()  
    print("Band:", rh_band)
    print("Description:", b.GetDescription())
    print("GRIB_ELEMENT:", md.get("GRIB_ELEMENT"))
    print("GRIB_COMMENT:", md.get("GRIB_COMMENT"))
    print("GRIB_UNIT:", md.get("GRIB_UNIT"))
    print("GRIB_VALID_TIME:", md.get("GRIB_VALID_TIME"))
    print("GRIB_REF_TIME:", md.get("GRIB_REF_TIME"))

    arr = b.ReadAsArray().astype("float32")
    nodata = b.GetNoDataValue()
    if nodata is not None:
        arr[arr == nodata] = np.nan

    print("RH stats [%]: min=", np.nanmin(arr), "max=", np.nanmax(arr), "mean=", np.nanmean(arr))

inspect_rh_by_band(r"E:/dataset_month1/HA43_N20_202109010000_00000_GB", rh_band=27)
# Out:
# RasterCount: 46
# Band: 27
# Description: 2[m] HTGL (Specified height level above ground)
# GRIB_ELEMENT: RH
# GRIB_COMMENT: Relative humidity [%]
# GRIB_UNIT: [%]
# GRIB_VALID_TIME: 1630454400
# GRIB_REF_TIME: 1630454400
# RH stats [%]: min= 0.65746284 max= 0.99999976 mean= 0.8568832

# %%
# process the data and save as csv 
# !python C:/users/suliko/q34/25q3/thesis/fpcup_new/fpcup-main/Mygetmeteodata.py
